# %%
import skmob
from skmob.utils.plot import plot_gdf
from skmob.tessellation import tilers
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import warnings
from tqdm.notebook import tqdm
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', 500)

# %%
def toAdj(fdf, tess):
    names = list(tess.tile_ID.values)
    adj = pd.DataFrame(columns=names, index = names)
    for i, row in enumerate(fdf.itertuples(), 1):
         adj.at[str(row.origin), str(row.destination)] = row.flow
    return adj

def filter_tessellation_land(tessellation, shape_file_land):    
    tiles_in_land = gpd.sjoin(tessellation, shape_file_land, how='left', op='intersects')
    tiles_in_land = tiles_in_land.groupby(['tile_ID'],sort=False,as_index=False).first()    
    land = tiles_in_land.dropna()[['tile_ID', 'geometry']]
    water = tiles_in_land[tiles_in_land['index_right'].isnull()][['tile_ID', 'geometry']]     
    
    crs = {'init': 'epsg:4326'}    
    land = gpd.GeoDataFrame(land, crs=crs, geometry='geometry')
    water = gpd.GeoDataFrame(water, crs=crs, geometry='geometry')     
    return {"land":land, "water":water}

# %%
#create Filtered/BikeNYC folder if it does not exist
if not os.path.exists('Filtered/BikeNYC'):
    os.makedirs('Filtered/BikeNYC')

# %%
for i in tqdm(range (1,13)):
    for year in range (2018,2020):
        df = pd.read_csv('./data/BikeNYC/'  +str(year) + "%.2d" % i +'-citibike-tripdata.csv')
        df['start_date'] =  pd.to_datetime(df['starttime']).dt.strftime('%Y-%m-%d')
        df['stop_date'] =  pd.to_datetime(df['stoptime']).dt.strftime('%Y-%m-%d')
        df = df[df['start_date'] == df['stop_date']]

        df['date'] = df['start_date']
        df = df[['date','start station latitude', 'start station longitude', 'end station latitude', 'end station longitude']]

        df_start = df[['date', 'start station latitude', 'start station longitude']]
        df_start['ind'] = df_start.index
        df_start['lat'] = df['start station latitude']
        df_start['lon'] = df['start station longitude']
        df_start = df_start[['date', 'lat', 'lon', 'ind']]


        df_end =  df[['date', 'end station latitude', 'end station longitude']]
        df_end['ind'] = df_end.index
        df_end['lat'] = df['end station latitude']
        df_end['lon'] = df['end station longitude']
        df_end = df_end[['date', 'lat', 'lon', 'ind']]

        result = pd.concat([df_start, df_end])
        result = result.sort_values(by=['ind'])

        data = result.groupby('date')

        for row,group in data:
            p = os.path.join('./Filtered/BikeNYC', "{}.csv".format(row))
            group.to_csv(p, index=False)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]

# %% [markdown]
# # From Tdf to Flow to AdjMatrix #

# %%
meters = 1827
tesselletion = tilers.tiler.get("squared", meters=meters, base_shape="New York City")

shape_file_land = gpd.read_file("NYC_shapeNoWaterArea.geojson")

shape_file_land_MAN = shape_file_land.iloc[[4]]

res_inter = filter_tessellation_land(tesselletion, shape_file_land_MAN )
tess_nyc = res_inter['land']

# %%
len(tess_nyc)
# Out:
# 64

# %%
plot_gdf(tess_nyc, style_func_args={'fillColor':'gray', 'color':'black', 'opacity': 0.2}, zoom = 9)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_509d3ed8ba913ce7a2ee9c6fdd16db6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_509d3ed8ba913ce7a2ee9c6fdd16db6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_509d3ed8ba913ce7a2ee9c6fdd16db6b = L.map(
#                 &quot;map_509d3ed8ba913ce7a2ee9c6fdd16db6b&quot;,
#                 {
#                     center: [40.77453849131864, -73.96778253166589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_509d3ed8ba913ce7a2ee9c6fdd16db6b);
#
#
#
#
#
#             var tile_layer_e6d415836f03a473ab9a350a46d78122 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e6d415836f03a473ab9a350a46d78122.addTo(map_509d3ed8ba913ce7a2ee9c6fdd16db6b);
#
#
#         function geo_json_346e62cec255bd085ad054e924a694a3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.25, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_346e62cec255bd085ad054e924a694a3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_346e62cec255bd085ad054e924a694a3 = L.geoJson(null, {
#                 onEachFeature: geo_json_346e62cec255bd085ad054e924a694a3_onEachFeature,
#
#                 style: geo_json_346e62cec255bd085ad054e924a694a3_styler,
#         });
#
#         function geo_json_346e62cec255bd085ad054e924a694a3_add (data) {
#             geo_json_346e62cec255bd085ad054e924a694a3
#                 .addData(data);
#         }
#             geo_json_346e62cec255bd085ad054e924a694a3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-74.06189635710963, 40.6884756395234], [-74.06189635710963, 40.700919297576796], [-74.04548413686877, 40.700919297576796], [-74.04548413686877, 40.6884756395234], [-74.06189635710963, 40.6884756395234]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_346e62cec255bd085ad054e924a694a3.addTo(map_509d3ed8ba913ce7a2ee9c6fdd16db6b);
#
#
#         function geo_json_9201710d2e5d2f740b6020dc7be410c2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.25, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_9201710d2e5d2f740b6020dc7be410c2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9201710d2e5d2f740b6020dc7be410c2 = L.geoJson(null, {
#                 onEachFeature: geo_json_9201710d2e5d2f740b6020dc7be410c2_onEachFeature,
#
#                 style: geo_json_9201710d2e5d2f740b6020dc7be410c2_styler,
#         });
#
#         function geo_json_9201710d2e5d2f740b6020dc7be410c2_add (data) {
#             geo_json_9201710d2e5d2f740b6020dc7be410c2
#                 .addData(data);
#         }
#             geo_json_9201710d2e5d2f740b6020dc7be410c2_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-74.04548413686877, 40.6884756395234], [-74.04548413686877, 40.700919297576796], [-74.0290719166279, 40.700919297576796], [-74.0290719166279, 40.6884756395234], [-74.04548413686877, 40.6884756395234]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_9201710d2e5d2f740b6020dc7be410c2.addTo(map_509d3ed8ba913ce7a2ee9c6fdd16db6b);
#
#
#         function geo_json_be4a6adad625d6fb9657752121a33948_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.25, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_be4a6adad625d6fb9657752121a33948_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_be4a6adad625d6fb9657752121a33948 = L.geoJson(null, {
#                 onEachFeature: geo_json_be4a6adad625d6fb9657752121a33948_onEachFeature,
#
#                 style: geo_json_be4a6adad625d6fb9657752121a33948_styler,
#         });
#
#         function geo_json_be4a6adad625d6fb9657752121a33948_add (data) {
#             geo_json_be4a6adad625

# %%
tess_nyc.to_file("NYC_tessellation.geojson", driver='GeoJSON')

# %% [markdown]
# # Reshaping #

# %%
from_directory = './Filtered/BikeNYC/'
to_directory = "../adj/BikeNYC/"

if not os.path.exists(to_directory):
    os.makedirs(to_directory)

i = 1
l = []

for filename in tqdm(os.listdir(from_directory)):
    
    base= os.path.basename(filename)
    name = os.path.splitext(base)[0]
    
    df = pd.read_csv(from_directory+filename)
    tdf = skmob.TrajDataFrame(df, latitude='lat', longitude='lon', 
                               user_id='ind', datetime='date')

    fdf = tdf.to_flowdataframe(tess_nyc, self_loops=True)

    adj = toAdj(fdf, tess_nyc)
    adj = adj.fillna(0)
    arr = adj.to_numpy()

    np.save(to_directory +name +'.npy', arr)    

    i += 1
# Out:
#   0%|          | 0/730 [00:00<?, ?it/s]

# %%
print(filename)
df = pd.read_csv(from_directory+filename)
df.head()
# Out:
# 2018-01-23.csv
#          date        lat        lon  ind
# 0  2018-01-23  40.767272 -73.993929  824
# 1  2018-01-23  40.755942 -74.002116  824
# 2  2018-01-23  40.743349 -74.006818  825
# 3  2018-01-23  40.767272 -73.993929  825
# 4  2018-01-23  40.751396 -74.005226  826

# %%
tdf = skmob.TrajDataFrame(df, latitude='lat', longitude='lon', 
                               user_id='ind', datetime='date')
